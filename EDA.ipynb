# %%
# Importing relevant libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('Downloads/Loan_Default.csv')

# %% [markdown]
# # Viewing the different variables and statistics of the data

# %%
df.head(10)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
# 5  24895  2019         cf              Joint           pre     type1
# 6  24896  2019         cf              Joint           pre     type1
# 7  24897  2019        NaN             Female         nopre     type1
# 8  24898  2019         cf              Joint         nopre     type1
# 9  24899  2019         cf  Sex Not Available         nopre     type3
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.isnull().sum()
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# ...

# %%
print(df.dtypes)
# Out:
# ID                             int64
# year                           int64
# loan_limit                    object
# Gender                        object
# approv_in_adv                 object
# loan_type                     object
# loan_purpose                  object
# Credit_Worthiness             object
# open_credit                   object
# business_or_commercial        object
# loan_amount                    int64
# rate_of_interest             float64
# Interest_rate_spread         float64
# Upfront_charges              float64
# term                         float64
# Neg_ammortization             object
# interest_only                 object
# lump_sum_payment              object
# property_value               float64
# construction_type             object
# occupancy_type                object
# Secured_by                    object
# total_units                   object
# income                       float64
# credit_type                   object
# ...

# %%
#checking duplicates 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# #### **Distribution of Target Variable [Status]**

# %%
sns.countplot(x='Status', data=df)
plt.title('Distribution of default status')
plt.show()


# Calculate the counts of default and non-default loans
default_counts = df['Status'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(default_counts, labels=default_counts.index, autopct='%1.1f%%', colors=['lightblue', 'lightcoral'], startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title('Default Status Distribution with Percentage')
plt.axis('equal')  
plt.show()

# %% [markdown]
# #### **Distribution of missing values**

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# #### **Relationship between default status and other variables**

# %%
sns.pairplot(df, hue='Status', palette='coolwarm')
plt.title('Pairplot of Features Colored Default Status')
plt.show()

# %% [markdown]
# #### **Relationship between loan type and default status**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='loan_type', hue='Status', palette='viridis')
plt.title('Loan Type vs. Default Status')
plt.xlabel('Loan Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### **Distribution of loan amount**

# %%
sns.displot(df['loan_amount'].dropna(),kde=True,color='darkred',bins=30)

# %% [markdown]
# #### **Identifying relationship between gender and default status**

# %%
fig,ax=plt.subplots()
sns.barplot(data=df,x='Status',y='income',hue='Gender')
fig.set_size_inches([12,6])
plt.show()
